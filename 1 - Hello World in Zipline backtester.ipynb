# %% [markdown]
# # Hello World in Zipline backtester
# ## 1. Dependencies

# %%
# zipline's magic command for enabling support to run in jupyter notebook
# %load_ext zipline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# ## 2. Define Zipline backtest functions
# Below is the simplest example on how to define a strategy and backtest with zipline
#
# TODO: using the custom dataset ingested in the notebook `0 - Preparing custom dataset for Zipline`

# %%
from zipline.api import order, record, symbol

def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))
    
def analyze(context, perf):
    plt.plot(perf.portfolio_value)
    plt.ylabel('portfolio $ value')
    plt.legend(loc=0)
    plt.show()

# %%
# perform the backtest inline in jupyter notebook
#%zipline --bundle fxcm_daily --trading-calendar forex --start 2008-1-3 --end 2012-1-1 -o backtest.pickle
# %zipline --bundle quantopian-quandl --start 2008-1-3 --end 2012-1-1 -o backtest.pickle
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-03 21:00:00+00:00  194.930              NaN             0.000000e+00
# 2008-01-04 21:00:00+00:00  180.050         0.000001            -9.102500e-08
# 2008-01-07 21:00:00+00:00  177.640         0.000023            -2.590845e-06
# 2008-01-08 21:00:00+00:00  171.250         0.000097            -1.545747e-05
# 2008-01-09 21:00:00+00:00  179.400         0.000217             8.901830e-06
# 2008-01-10 21:00:00+00:00  178.020         0.000200             3.291820e-06
# 2008-01-11 21:00:00+00:00  172.690         0.000245            -2.344552e-05
# 2008-01-14 21:00:00+00:00  178.780         0.000319             1.300409e-05
# 2008-01-15 21:00:00+00:00  169.040         0.000475            -5.526143e-05
# 2008-01-16 21:00:00+00:00  159.640         0.000567            -1.305423e-04
# 2008-01-17 21:00:00+00:00  160.890         0.000550            -1.193737e-04
# ...

# %%
# the backtest result can also be loaded from disk and analyzed
df = pd.read_pickle("backtest.pickle")
df.portfolio_value.plot()
plt.show()
