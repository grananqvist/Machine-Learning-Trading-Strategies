# %% [markdown]
# ## Installing Zipline
# You should be able to install zipline by using pip. If it doesn't work, there are other ways to install zipline that you can look up.
#
# #### 1. install zipline
# ```
# pip install zipline
# ```
# #### 2.  I had to upgrade some packages
# ```
# pip install -U pip
# pip install -U numpy
# ```
# #### 3. Register on Quandl and get an API key
# https://www.quandl.com/account/api
#
# #### 4. Download data from Quandl to zipline
# ```
# QUANDL_API_KEY=<yourkey> zipline ingest -b quandl
# ```

# %% [markdown]
# ## Initializing zipline for jupyter notebook

# %%
# zipline's magic command for enabling support to run in jupyter notebook
# %load_ext zipline

# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# ## Backtest with Zipline
# Below is the simplest example on how to define a strategy and backtest with zipline

# %%
from zipline.api import order, record, symbol

def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))
    
def analyze(context, perf):
    plt.plot(perf.portfolio_value)
    plt.ylabel('portfolio $ value')
    plt.legend(loc=0)
    plt.show()

# %%
# perform the backtest inline in jupyter notebook
# %zipline --bundle quantopian-quandl --start 2008-1-1 --end 2012-1-1 -o backtest.pickle
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00  194.840              NaN             0.000000e+00
# 2008-01-03 21:00:00+00:00  194.930         0.000001            -9.846500e-08
# 2008-01-04 21:00:00+00:00  180.050         0.000137            -1.506949e-05
# 2008-01-07 21:00:00+00:00  177.640         0.000112            -1.997931e-05
# 2008-01-08 21:00:00+00:00  171.250         0.000140            -3.923593e-05
# 2008-01-09 21:00:00+00:00  179.400         0.000290            -6.726635e-06
# 2008-01-10 21:00:00+00:00  178.020         0.000267            -1.371664e-05
# 2008-01-11 21:00:00+00:00  172.690         0.000299            -4.578399e-05
# 2008-01-14 21:00:00+00:00  178.780         0.000379            -3.244380e-06
# 2008-01-15 21:00:00+00:00  169.040         0.000529            -8.124990e-05
# 2008-01-16 21:00:00+00:00  159.640         0.000621            -1.659307e-04
# ...

# %%
# the backtest result can also be loaded from disk and analyzed
df = pd.read_pickle("backtest.pickle")
df.portfolio_value.plot()
plt.show()
